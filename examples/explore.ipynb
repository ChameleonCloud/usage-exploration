# %%
# %load_ext autoreload
# %autoreload 2

# %%
from chameleon_usage.pipeline import UsagePipeline
from chameleon_usage.utils import load_sites_yaml

config = load_sites_yaml("../etc/sites.yaml")
tacc_pipeline = UsagePipeline(config["chi_tacc"])

# %%
from chameleon_usage.plots import plot_legacy_usage

legacy_data = tacc_pipeline.span_loader.legacy_usage.collect()
print(legacy_data)

# %%
plot_legacy_usage(legacy_data)
